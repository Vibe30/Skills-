# %% [markdown]
# # Data Visualization with Matplotlib

# %% [markdown]
# RUN THE CELL BELOW AND START SOLVING

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# Plot (x,y) axes and set the labels and titles <br>
# Use ax.plot function to plot a simple sinusoid to match the plot below <br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
time = np.arange(0, 10, 0.1);
amp   = np.sin(time)
plt.plot(time, amp)
plt.title('A Sine Curve')

plt.xlabel('x')

plt.ylabel('sin(x)')

plt.grid(True, which='both')

plt.show()

# %%
# your code here

# %% [markdown]
# Use Scatter Plots to draw below as the given output <br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
time = np.arange(0, 10, 0.3);
amp  = np.sin(time)
plt.scatter(time, amp, alpha=1 , c = "black")

plt.grid(True, which='both')

plt.show()

# %%
# your code here-

# %% [markdown]
# use line and color codes to plot points along with a line connecting them<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
time = np.arange(0, 10, 0.3);
amp   = np.sin(time)
plt.scatter(time, amplitude, alpha=1 , c = "black")
plt.plot(time, amp, c = 'black')
plt.grid(True, which='both')

plt.show()

# %%
#your code here-

# %% [markdown]
# create a single figure with multiple lines as follows<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
time = np.arange(0, 10, 0.1);
amp   = np.sin(time)
amp2 = np.sin(time + (np.pi/2)) 
plt.plot(time, amp2  , c ='orange')
plt.plot(time, amp)


plt.grid(True, which='both')

plt.show()

# %%
# your code here-

# %% [markdown]
# Create the plot given below in the output by using 'linestyle'  keyword.<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');


plt.plot(x, x + 4, linestyle='-')  
plt.plot(x, x + 5, linestyle='--') 
plt.plot(x, x + 6, linestyle='-.') 
plt.plot(x, x + 7, linestyle=':');

# %%
# your code here-

# %% [markdown]
# use 'linestyle' and 'color' keyword  to draw as given below in the output<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
plt.plot(x, x + 0, '-g')  
plt.plot(x, x + 1, '--c')
plt.plot(x, x + 2, '-.k') 
plt.plot(x, x + 3, ':r');

# %%
# your code here-

# %% [markdown]
# # GOOD JOB!!
